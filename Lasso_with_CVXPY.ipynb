# %%
from cvxpy import *
import numpy as np
import cvxopt
from multiprocessing import Pool

# Problem data.
n = 10
m = 5
A = cvxopt.normal(n,m)
b = cvxopt.normal(n)
gamma = Parameter(sign="positive")

# Construct the problem.
x = Variable(m)
objective = Minimize(sum_squares(A*x - b) + gamma*norm(x, 1))
p = Problem(objective)

# Assign a value to gamma and find the optimal x.
def get_x(gamma_value):
    gamma.value = gamma_value
    result = p.solve()
    return x.value

gammas = np.logspace(-1, 2, num=100)
# Serial computation.
x_values = [get_x(value) for value in gammas]

# Parallel computation.
pool = Pool(processes = 4)
par_x = pool.map(get_x, gammas)

for v1,v2 in zip(x_values, par_x):
    if np.linalg.norm(v1 - v2) > 1e-5:
        print "error"

# %%
whos
# Out:
# Variable                Type         Data/Info
# ----------------------------------------------
# A                       matrix       [-1.34e+00  7.24e-01 -8.3<...>02  1.22e+00  1.00e+00]\n
# Bool                    ABCMeta      <class 'cvxpy.expressions<...>variables.bool_var.Bool'>
# CVXOPT                  str          CVXOPT
# CallbackParam           ABCMeta      <class 'cvxpy.expressions<...>ack_param.CallbackParam'>
# Constant                ABCMeta      <class 'cvxpy.expressions<...>tants.constant.Constant'>
# ECOS                    str          ECOS
# ECOS_BB                 str          ECOS_BB
# INFEASIBLE              str          infeasible
# INFEASIBLE_INACCURATE   str          infeasible_inaccurate
# Int                     ABCMeta      <class 'cvxpy.expressions.variables.int_var.Int'>
# Maximize                ABCMeta      <class 'cvxpy.problems.objective.Maximize'>
# Minimize                ABCMeta      <class 'cvxpy.problems.objective.Minimize'>
# OPTIMAL                 str          optimal
# OPTIMAL_INACCURATE      str          optimal_inaccurate
# Parameter               ABCMeta      <class 'cvxpy.expressions<...>nts.parameter.Parameter'>
# Pool                    function     <function Pool at 0x101a47b90>
# Problem                 ABCMeta      <class 'cvxpy.problems.problem.Problem'>
# SCS                     str          SCS
# SOLVER_ERROR            str          solver_error
# Semidef                 function     <function Semidef at 0x106cf9ed8>
# SolverError             type         <class 'cvxpy.error.SolverError'>
# UNBOUNDED               str          unbounded
# UNBOUNDED_INACCURATE    str          unbounded_inaccurate
# Variable                ABCMeta      <class 'cvxpy.expressions<...>ables.variable.Variable'>
# abs                     ABCMeta      <class 'cvxpy.atoms.elementwise.abs.abs'>
# affine                  module       <module 'cvxpy.atoms.affi<...>oms/affine/__init__.pyc'>
# atom                    module       <module 'cvxpy.atoms.atom<...>es/cvxpy/atoms/atom.pyc'>
# atoms                   module       <module 'cvxpy.atoms' fro<...>vxpy/atoms/__init__.pyc'>
# b                       matrix       [ 1.13e+00]\n[ 1.79e-01]\<...>-1.13e+00]\n[-1.17e+00]\n
# constraints             module       <module 'cvxpy.constraint<...>onstraints/__init__.pyc'>
# conv                    ABCMeta      <class 'cvxpy.atoms.affine.conv.conv'>
# cvxopt                  module       <module 'cvxopt' from '/U<...>ges/cvxopt/__init__.pyc'>
# diag                    function     <function diag at 0x1071c81b8>
# elementwise             module       <module 'cvxpy.atoms.elem<...>lementwise/__init__.pyc'>
# entr                    ABCMeta      <class 'cvxpy.atoms.elementwise.entr.entr'>
# error                   module       <module 'cvxpy.error' fro<...>ackages/cvxpy/error.pyc'>
# exp                     ABCMeta      <class 'cvxpy.atoms.elementwise.exp.exp'>
# expressions             module       <module 'cvxpy.expression<...>xpressions/__init__.pyc'>
# gamma                   Parameter    param0
# gammas                  ndarray      100: 100 elems, type `float64`, 800 bytes
# geo_mean                ABCMeta      <class 'cvxpy.atoms.eleme<...>twise.geo_mean.geo_mean'>
# get_x                   function     <function get_x at 0x107270848>
# hstack                  ABCMeta      <class 'cvxpy.atoms.affine.hstack.hstack'>
# huber                   ABCMeta      <class 'cvxpy.atoms.elementwise.huber.huber'>
# interface               module       <module 'cvxpy.interface'<...>/interface/__init__.pyc'>
# inv_pos                 ABCMeta      <class 'cvxpy.atoms.elementwise.inv_pos.inv_pos'>
# kl_div                  ABCMeta      <class 'cvxpy.atoms.kl_div.kl_div'>
# lambda_max              ABCMeta      <class 'cvxpy.atoms.lambda_max.lambda_max'>
# lambda_min              ABCMeta      <class 'cvxpy.atoms.lambda_min.lambda_min'>
# lambda_sum_largest      function     <function lambda_sum_largest at 0x107184f50>
# lambda_sum_smallest     function     <function lambda_sum_smallest at 0x107184500>
# lin_ops                 module       <module 'cvxpy.lin_ops' f<...>py/lin_ops/__init__.pyc'>
# log                     ABCMeta      <class 'cvxpy.atoms.elementwise.log.log'>
# log1p                   ABCMeta      <class 'cvxpy.atoms.elementwise.log1p.log1p'>
# log_det                 ABCMeta      <class 'cvxpy.atoms.log_det.log_det'>
# log_sum_exp             ABCMeta      <class 'cvxpy.atoms.log_sum_exp.log_sum_exp'>
# m                       int          5
# matrix_frac             ABCMeta      <class 'cvxpy.atoms.matrix_frac.matrix_frac'>
# max_elemwise            ABCMeta      <class 'cvxpy.atoms.eleme<...>x_elemwise.max_elemwise'>
# max_entries             ABCMeta      <class 'cvxpy.atoms.max_entries.max_entries'>
# min_elemwise            ABCMeta      <class 'cvxpy.atoms.eleme<...>n_elemwise.min_elemwise'>
# min_entries             ABCMeta      <class 'cvxpy.atoms.min_entries.min_entries'>
# mixed_norm              function     <function mixed_norm at 0x1071b2c08>
# mul_elemwise            ABCMeta      <class 'cvxpy.atoms.affin<...>l_elemwise.mul_elemwise'>
# n                       int          10
# neg                     function     <function neg at 0x1071e1938>
# norm                    function     <function norm at 0x1071ada28>
# norm1                   ABCMeta      <class 'cvxpy.atoms.norm1.norm1'>
# norm2                   ABCMeta      <class 'cvxpy.atoms.norm2.norm2'>
# normInf                 ABCMeta      <class 'cvxpy.atoms.norm_inf.normInf'>
# normNuc                 ABCMeta      <class 'cvxpy.atoms.norm_nuc.normNuc'>
# norm_inf                module       <module 'cvxpy.atoms.norm<...>vxpy/atoms/norm_inf.pyc'>
# norm_largest            function     <function norm_largest at 0x1071b2140>
# norm_nuc                module       <module 'cvxpy.atoms.norm<...>vxpy/atoms/norm_nuc.pyc'>
# np                      module       <module 'numpy' from '/Us<...>ages/numpy/__init__.pyc'>
# objective               Minimize     minimize square(norm2([[-<...>)) + param0 * norm1(var1)
# p                       Problem      minimize square(norm2([[-<...>)) + param0 * norm1(var1)
# par_x                   list         n=100
# pool                    Pool         <multiprocessing.pool.Pool object at 0x10728ead0>
# pos                     function     <function pos at 0x1071e1aa0>
# problems                module       <module 'cvxpy.problems' <...>y/problems/__init__.pyc'>
# quad_form               function     <function quad_form at 0x1071b6758>
# quad_over_lin           ABCMeta      <class 'cvxpy.atoms.quad_over_lin.quad_over_lin'>
# reshape                 ABCMeta      <class 'cvxpy.atoms.affine.reshape.reshape'>
# scalene                 function     <function scalene at 0x1071e19b0>
# semidefinite            function     <function Semidef at 0x106cf9ed8>
# settings                module       <module 'cvxpy.settings' <...>ages/cvxpy/settings.pyc'>
# sigma_max               ABCMeta      <class 'cvxpy.atoms.sigma_max.sigma_max'>
# sqrt                    ABCMeta      <class 'cvxpy.atoms.elementwise.sqrt.sqrt'>
# square                  ABCMeta      <class 'cvxpy.atoms.elementwise.square.square'>
# sum_entries             ABCMeta      <class 'cvxpy.atoms.affin<...>sum_entries.sum_entries'>
# sum_largest             ABCMeta      <class 'cvxpy.atoms.sum_largest.sum_largest'>
# sum_smallest            function     <function sum_smallest at 0x1071be398>
# sum_squares             function     <function sum_squares at 0x1071be500>
# total_variation         module       <module 'cvxpy.atoms.tota<...>oms/total_variation.pyc'>
# trace                   ABCMeta      <class 'cvxpy.atoms.affine.trace.trace'>
# tv                      function     <function tv at 0x1071beed8>
# upper_tri               ABCMeta      <class 'cvxpy.atoms.affine.upper_tri.upper_tri'>
# utilities               module       <module 'cvxpy.utilities'<...>/utilities/__init__.pyc'>
# v1                      matrix       [[ -5.08433341e-12]\n [ -<...>12]\n [ -1.39336028e-12]]
# v2                      matrix       [[ -5.08433341e-12]\n [ -<...>12]\n [ -1.39336028e-12]]
# value                   float64      100.0
# vec                     function     <function vec at 0x1071ce578>
# vstack                  ABCMeta      <class 'cvxpy.atoms.affine.vstack.vstack'>
# x                       Variable     var1
# x_values                list         n=100
